# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#import ase
#import gudhi
import os
from glob import glob

from numba import jit
from tqdm import tqdm_notebook

from sklearn.externals import joblib as jl

import warnings
warnings.filterwarnings("ignore")

# %%
class HorizontalDisplay:
    def __init__(self, *args):
        self.args = args

    def _repr_html_(self):
        template = '<div style="float: left; padding: 10px;">{0}</div>'
        return "\n".join(template.format(arg._repr_html_())
                         for arg in self.args)

# %%
@jit(nopython=True)
def normalize(v):
    return v / np.linalg.norm(v)

# %%
normalize(np.array([1.,2.,3.]))
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-42-eff29d6f4ffd> in <module>()
# ----> 1 normalize(np.array([1.,2.,3.]))
#
# G:\intelpython3\lib\site-packages\numba\dispatcher.py in _compile_for_args(self, *args, **kws)
#     328                                 for i, err in failed_args))
#     329                 e.patch_message(msg)
# --> 330             raise e
#     331
#     332     def inspect_llvm(self, signature=None):
#
# G:\intelpython3\lib\site-packages\numba\dispatcher.py in _compile_for_args(self, *args, **kws)
#     305                 argtypes.append(self.typeof_pyval(a))
#     306         try:
# --> 307             return self.compile(tuple(argtypes))
#     308         except errors.TypingError as e:
#     309             # Intercept typing error that may be due to an argument
#
# G:\intelpython3\lib\site-packages\numba\dispatcher.py in compile(self, sig)
#     577
#     578                 self._cache_misses[sig] += 1
# --> 579                 cres = self._compiler.compile(args, return_type)
#     580                 self.add_overload(cres)
#     581                 self._cache.save_overload(sig, cres)
#
# G:\intelpython3\lib\site-packages\numba\dispatcher.py in compile(self, args, return_type)
#      78                                       impl,
#      79                                       args=args, return_type=return_type,
# ---> 80                                       flags=flags, locals=self.locals)
#      81         # Check typing error if object mode is used
#      82         if cres.typing_error is not None and not flags.enable_pyobject:
#
# G:\intelpython3\lib\site-packages\numba\compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library)
#     761     pipeline = Pipeline(typingctx, targetctx, library,
#     762                         args, return_type, flags, locals)
# --> 763     return pipeline.compile_extra(func)
#     764
#     765
#
# G:\intelpython3\lib\site-packages\numba\compiler.py in compile_extra(self, func)
#     358         self.lifted = ()
#     359         self.lifted_from = None
# --> 360         return self._compile_bytecode()
#     361
#     362     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# G:\intelpython3\lib\site-packages\numba\compiler.py in _compile_bytecode(self)
#     720         """
#     721         assert self.func_ir is None
# --> 722         return self._compile_core()
#     723
#     724     def _compile_ir(self):
#
# G:\intelpython3\lib\site-packages\numba\compiler.py in _compile_core(self)
#     707
#     708         pm.finalize()
# --> 709         res = pm.run(self.status)
#     710         if res is not None:
#     711             # Early pipeline completion
#
# G:\intelpython3\lib\site-packages\numba\compiler.py in run(self, status)
#     244                     # No more fallback pipelines?
#     245                     if is_final_pipeline:
# --> 246                         raise patched_exception
#     247                     # Go to next fallback pipeline
#     248                     else:
#
# G:\intelpython3\lib\site-packages\numba\compiler.py in run(self, status)
#     236                 try:
#     237                     event(stage_name)
# --> 238                     stage()
#     239                 except _EarlyPipelineCompletion as e:
#     240                     return e.result
#
# G:\intelpython3\lib\site-packages\numba\compiler.py in stage_nopython_frontend(self)
#     450                 self.args,
#     451                 self.return_type,
# --> 452                 self.locals)
#     453
#     454         with self.fallback_context('Function "%s" has invalid return type'
#
# G:\intelpython3\lib\site-packages\numba\compiler.py in type_inference_stage(typingctx, interp, args, return_type, locals)
#     863
#     864         infer.build_constraint()
# --> 865         infer.propagate()
#     866         typemap, restype, calltypes = infer.unify()
#     867
#
# G:\intelpython3\lib\site-packages\numba\typeinfer.py in propagate(self, raise_errors)
#     842         if errors:
#     843             if raise_errors:
# --> 844                 raise errors[0]
#     845             else:
#     846                 return errors
#
# G:\intelpython3\lib\site-packages\numba\typeinfer.py in propagate(self, typeinfer)
#     135                                                    lineno=loc.line):
#     136                 try:
# --> 137                     constraint(typeinfer)
#     138                 except TypingError as e:
#     139                     errors.append(e)
#
# G:\intelpython3\lib\site-packages\numba\typeinfer.py in __call__(self, typeinfer)
#     160     def __call__(self, typeinfer):
#     161         with new_error_context("typing of assignment at {0}", self.loc):
# --> 162             typeinfer.copy_type(self.src, self.dst, loc=self.loc)
#     163             # If `dst` is refined, notify us
#     164             typeinfer.refine_map[self.dst] = self
#
# G:\intelpython3\lib\site-packages\numba\typeinfer.py in copy_type(self, src_var, dest_var, loc)
#     860
#     861     def copy_type(self, src_var, dest_var, loc):
# --> 862         unified = self.typevars[dest_var].union(self.typevars[src_var], loc=loc)
#     863
#     864     def lock_type(self, var, tp, loc, literal_value=NOTSET):
#
# G:\intelpython3\lib\site-packages\numba\typeinfer.py in union(self, other, loc)
#      87     def union(self, other, loc):
#      88         if other.type is not None:
# ---> 89             self.add_type(other.type, loc=loc)
#      90
#      91         return self.type
#
# G:\intelpython3\lib\site-packages\numba\typeinfer.py in add_type(self, tp, loc)
#      58                     raise TypingError(msg % (self.type, tp, self.var,
#      59                                              self.define_loc),
# ---> 60                                       loc=loc)
#      61             else:
#      62                 # First time definition
#
# TypingError: Failed at nopython (nopython frontend)
# cannot unify array(float32, 1d, C) and float64 for 'tmp', defined at <ipython-input-41-be1337693c38> (4)
# File "<ipython-input-41-be1337693c38>", line 6
# [1] During: typing of assignment at <ipython-input-41-be1337693c38> (6)

# %%
train = pd.read_csv("../input/train.csv", engine='c')
test = pd.read_csv("../input/test.csv", engine='c')
structs = pd.read_csv("../input/structures.csv", engine='c')

# %%
structs.describe()
# Out:
#          atom_index             x             y             z
# count  2.358657e+06  2.358657e+06  2.358657e+06  2.358657e+06
# mean   8.757349e+00  9.489178e-02 -3.337381e-01  6.241504e-02
# std    5.592487e+00  1.655271e+00  1.989152e+00  1.445870e+00
# min    0.000000e+00 -9.234889e+00 -9.933938e+00 -9.134765e+00
# 25%    4.000000e+00 -8.746097e-01 -1.826156e+00 -8.424896e-01
# 50%    9.000000e+00  5.183615e-02 -4.035932e-01  1.093207e-02
# 75%    1.300000e+01  1.116101e+00  1.373660e+00  9.394357e-01
# max    2.800000e+01  9.382240e+00  1.018196e+01  7.894733e+00

# %%
name = "dsgdb9nsd_000001" # from train

HorizontalDisplay(
    train[train.molecule_name == name],
    structs[structs.molecule_name == name]
)
# Out:
# <div style="float: left; padding: 10px;"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>molecule_name</th>
#       <th>atom_index_0</th>
#       <th>atom_index_1</th>
#       <th>type</th>
#       <th>scalar_coupling_constant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>dsgdb9nsd_000001</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1JHC</td>
#       <td>84.8076</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>dsgdb9nsd_000001</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2JHH</td>
#       <td>-11.2570</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>dsgdb9nsd_000001</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2JHH</td>
#       <td>-11.2548</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>dsgdb9nsd_000001</td>
#       <td>1</td>
#       <td>4</td>
#       <td>2JHH</td>
#       <td>-11.2543</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>dsgdb9nsd_000001</td>
#       <td>2</td>
#       <td>0</td>
#       <td>1JHC</td>
#       <td>84.8074</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>dsgdb9nsd_000001</td>
#       <td>2</td>
#       <td>3</td>
#       <td>2JHH</td>
#       <td>-11.2541</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>dsgdb9nsd_000001</td>
#       <td>2</td>
#       <td>4</td>
#       <td>2JHH</td>
#       <td>-11.2548</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>dsgdb9nsd_000001</td>
#       <td>3</td>
#       <td>0</td>
#       <td>1JHC</td>
#       <td>84.8093</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>dsgdb9nsd_000001</td>
#       <td>3</td>
#       <td>4</td>
#       <td>2JHH</td>
#       <td>-11.2543</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>dsgdb9nsd_000001</td>
#       <td>4</td>
#       <td>0</td>
#       <td>1JHC</td>
#       <td>84.8095</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left; padding: 10px;"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>molecule_name</th>
#       <th>atom_index</th>
#       <th>atom</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>dsgdb9nsd_000001</td>
#       <td>0</td>
#       <td>C</td>
#       <td>-0.012698</td>
#       <td>1.085804</td>
#       <td>0.008001</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>dsgdb9nsd_000001</td>
#       <td>1</td>
#       <td>H</td>
#       <td>0.002150</td>
#       <td>-0.006031</td>
#       <td>0.001976</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>dsgdb9nsd_000001</td>
#       <td>2</td>
#       <td>H</td>
#       <td>1.011731</td>
#       <td>1.463751</td>
#       <td>0.000277</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>dsgdb9nsd_000001</td>
#       <td>3</td>
#       <td>H</td>
#       <td>-0.540815</td>
#       <td>1.447527</td>
#       <td>-0.876644</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>dsgdb9nsd_000001</td>
#       <td>4</td>
#       <td>H</td>
#       <td>-0.523814</td>
#       <td>1.437933</td>
#       <td>0.906397</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %%
@jit(nopython=True)
def two_point_standardization(struct, idx0, idx1):
    
    coo0 = struct[idx0]
    coo1 = struct[idx1]
    
    if np.linalg.norm(coo1) < np.linalg.norm(coo0):
        
        tmp = coo0
        coo0  = coo1
        coo1 = tmp
    
    normal = (coo1 - coo0) / 2
    
    normal_unit = normalize(normal)
    
    vec0 = coo0 + normal
    
    # Plane Equation
    d = -vec0 @ normal
    plane = lambda x, y: (-normal[0] * x - normal[1] * y - d) / normal[2] if 0 != normal[2] else 0.
    #
    
    # Make orthonormal basis on plane
    u_x = 1
    u_y = 0
    
    u = np.array([u_x, u_y, plane(u_x + vec0[0], u_y + vec0[1]) - vec0[2]])
    
    ## Cross product
    a1, a2, a3 = u
    b1, b2, b3 = normal
    
    v = np.array(
        [
            a2 * b3 - a3 * b2,
            a3 * b1 - a1 * b3,
            a1 * b2 - a2 * b1
        ]
    ) 
    ##
    
    u_unit = normalize(u)
    v_unit = normalize(v)
    #

    # Change of basis
    basis_matrix = np.vstack((normal_unit, u_unit, v_unit)).T    
    transform_matrix = np.linalg.inv(basis_matrix)
    
    return transform_matrix @ (struct - vec0).T
    #

# %%
@jit()
def get_classified_idx(struct, tgt0, tgt1): 

    standardized = np.around(two_point_standardization(struct.values, tgt0, tgt1), decimals=14)
    
    print(standardized)
    
    struct['x_changed'] = standardized[0]
    struct['norm'] = np.linalg.norm(standardized, axis=0)

    if 0 < struct.x_changed[tgt0]:
        struct.x_changed *= -1

    I = struct[0 > struct.x_changed]
    II = struct[0 < struct.x_changed]
    
    return \
        l2s(I[struct.x_changed[tgt0] >= I.x_changed].sort_values(by=['norm'], ascending=False).index.values), \
        l2s(I[struct.x_changed[tgt0] <= I.x_changed].sort_values(by=['norm'], ascending=False).index.values), \
        l2s(II[struct.x_changed[tgt1] >= II.x_changed].sort_values(by=['norm'], ascending=False).index.values), \
        l2s(II[struct.x_changed[tgt1] <= II.x_changed].sort_values(by=['norm'], ascending=False).index.values)

# %%
l2s = lambda l: str(list(l))[1:-1]
s2l = lambda s: list(map(int, s.split(', ')))

seg_id = 0
singular_avoiding = 10

inf_to_tgt_I = []
center_to_tgt_I = []
center_to_tgt_II = []
inf_to_tgt_II = []

for idx in tqdm_notebook(np.array_split(train.index, 4)[seg_id]):

    name = train.molecule_name[idx]
    tgt0 = int(train.atom_index_0[idx])
    tgt1 = int(train.atom_index_1[idx])
    target_frame = structs[structs.molecule_name == name].reset_index()
    
    classified = get_classified_idx(target_frame[['x','y','z']]+singular_avoiding, tgt0, tgt1)
    
    inf_to_tgt_I.append(classified[0])
    center_to_tgt_I.append(classified[1])
    center_to_tgt_II.append(classified[2])
    inf_to_tgt_II.append(classified[3])
    
jl.dump(inf_to_tgt_I, f'inf_to_tgt_I_{seg_id}.pkl')
jl.dump(center_to_tgt_I, f'center_to_tgt_I_{seg_id}.pkl')
jl.dump(center_to_tgt_II, f'center_to_tgt_II{seg_id}.pkl')
jl.dump(inf_to_tgt_II, f'inf_to_tgt_II{seg_id}.pkl')
# Out:
# A Jupyter Widget
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-36493ed91567> in <module>()
#      15     tgt0 = int(train.atom_index_0[idx])
#      16     tgt1 = int(train.atom_index_1[idx])
# ---> 17     target_frame = structs[structs.molecule_name == name].reset_index()
#      18
#      19     classified = get_classified_idx(target_frame[['x','y','z']]+singular_avoiding, tgt0, tgt1)
#
# G:\intelpython3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# G:\intelpython3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# KeyboardInterrupt:

# %%
idx = 128382
    
name = train.molecule_name[idx]
tgt0 = int(train.atom_index_0[idx])
tgt1 = int(train.atom_index_1[idx])
target_frame = structs[structs.molecule_name == name].reset_index()
classified = get_classified_idx(target_frame[['x','y','z']]+10, tgt0, tgt1)

print(classified)
classified = get_classified_idx(target_frame[['x','y','z']], tgt0, tgt1)

print(classified)
# Out:
# [[-1.36169339 -0.4174461   0.86083976  1.77048544  2.98400448  3.3542545
#    2.32254456  1.29403376 -0.98664231 -2.3189436  -1.54464033 -0.81307842
#    1.36169339  0.74705284  4.32916601  2.14512247]
#  [-0.          0.06732314 -0.56391974 -0.56222389 -0.12168254 -0.39397375
#   -0.99096389 -1.11241278  0.59870924  0.42686496 -1.022304   -0.38392787
#   -0.         -1.60351894 -0.13538624 -1.36472091]
#  [ 0.          1.10648347  0.79249869  1.97354853  2.06837794  3.38096917
#    4.01770779  3.12367567 -0.83790059  0.31152714 -0.37893272  1.9243207
#    0.          0.42484429  3.76211316  5.01108715]]
# ('14, 15, 5, 6, 4, 3, 12', '7, 13, 12, 2', '11, 8, 0, 1', '9, 10, 0')
# [[-1.36169339 -0.4174461   0.86083976  1.77048544  2.98400448  3.3542545
#    2.32254456  1.29403376 -0.98664231 -2.3189436  -1.54464033 -0.81307842
#    1.36169339  0.74705284  4.32916601  2.14512247]
#  [ 0.          0.06732314 -0.56391974 -0.56222389 -0.12168254 -0.39397375
#   -0.99096389 -1.11241278  0.59870924  0.42686496 -1.022304   -0.38392787
#   -0.         -1.60351894 -0.13538624 -1.36472091]
#  [-0.          1.10648347  0.79249869  1.97354853  2.06837794  3.38096917
#    4.01770779  3.12367567 -0.83790059  0.31152714 -0.37893272  1.9243207
#    0.          0.42484429  3.76211316  5.01108715]]
# ('14, 15, 5, 6, 4, 3, 12', '7, 13, 12, 2', '11, 8, 0, 1', '9, 10, 0')

# %%
np.around(1.123e-13, decimals=13)
# Out:
# 1e-13
